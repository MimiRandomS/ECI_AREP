# %%
# %pip install openai python-dotenv
# Out:
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------- -------- 0.8/1.0 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------- -------- 1.6/2.0 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.7 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/16 [typing-inspection]
#    ----------------------------------------  0/16 [typing-inspection]
#    -- -------------------------------------  1/16 [tqdm]
#    -- -------------------------------------  1/16 [tqdm]
#    -- -------------------------------------  1/16 [tqdm]
#    -- -------------------------------------  1/16 [tqdm]
#    -- -------------------------------------  1/16 [tqdm]
#    -- -------------------------------------  1/16 [tqdm]
# ...
